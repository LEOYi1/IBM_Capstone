# %%
# !pip install --force-reinstall ibm_db==3.1.0 ibm_db_sa==0.3.3
# !pip uninstall sqlalchemy==1.4 -y && pip install sqlalchemy==1.3.24
# !pip install ipython-sql
# %load_ext sql
# Out:
# ...
#   Using cached ibm_db-3.1.0-cp39-cp39-linux_x86_64.whl
# ...
#   Using cached ibm_db_sa-0.3.3-py3-none-any.whl
# ...
#   Using cached SQLAlchemy-1.4.40-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
# ...
#   Using cached greenlet-1.1.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (154 kB)
# ...
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 1.1.3
#     Uninstalling greenlet-1.1.3:
#       Successfully uninstalled greenlet-1.1.3
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.3.24
#     Uninstalling SQLAlchemy-1.3.24:
#       Successfully uninstalled SQLAlchemy-1.3.24
#   Attempting uninstall: ibm-db-sa
#     Found existing installation: ibm-db-sa 0.3.3
#     Uninstalling ibm-db-sa-0.3.3:
#       Successfully uninstalled ibm-db-sa-0.3.3
#   Attempting uninstall: ibm-db
#     Found existing installation: ibm-db 3.1.0
#     Uninstalling ibm-db-3.1.0:
# ...

# %%
# %sql ibm_db_sa://njg88036:cn9b2q6fnRY4PQWD@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB?security=SSL

# %% [markdown]
# ### Task 1

# %%
# %%sql
#
# select distinct (Launch_Site) from SPACEXTBL
# Out:
#  * ibm_db_sa://njg88036:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB
# Done.
# [('CCAFS LC-40',), ('CCAFS SLC-40',), ('KSC LC-39A',), ('VAFB SLC-4E',)]

# %% [markdown]
# ### Task 2

# %%
# %%sql
#
# select * from SPACEXTBL where Launch_Site like 'CCA%'
# limit 5
# Out:
#  * ibm_db_sa://njg88036:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB
# Done.
# [(datetime.date(2010, 6, 4), datetime.time(18, 45), 'F9 v1.0  B0003', 'CCAFS LC-40', 'Dragon Spacecraft Qualification Unit', 0, 'LEO', 'SpaceX', 'Success', 'Failure (parachute)'),
#  (datetime.date(2010, 12, 8), datetime.time(15, 43), 'F9 v1.0  B0004', 'CCAFS LC-40', 'Dragon demo flight C1, two CubeSats, barrel of Brouere cheese', 0, 'LEO (ISS)', 'NASA (COTS) NRO', 'Success', 'Failure (parachute)'),
#  (datetime.date(2012, 5, 22), datetime.time(7, 44), 'F9 v1.0  B0005', 'CCAFS LC-40', 'Dragon demo flight C2', 525, 'LEO (ISS)', 'NASA (COTS)', 'Success', 'No attempt'),
#  (datetime.date(2012, 10, 8), datetime.time(0, 35), 'F9 v1.0  B0006', 'CCAFS LC-40', 'SpaceX CRS-1', 500, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt'),
# ...

# %% [markdown]
# ### Task 3

# %%
# %%sql
#
# select SUM(PAYLOAD_MASS__KG_) as payloadmass_NASACRS from SPACEXTBL
# where Customer = 'NASA (CRS)'
# Out:
#  * ibm_db_sa://njg88036:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB
# Done.
# [(45596,)]

# %% [markdown]
# ### Task 4

# %%
# %%sql
#
# select AVG(PAYLOAD_MASS__KG_) as mean_payloadmassF9V11 from SPACEXTBL
# where Booster_Version = 'F9 v1.1'
# Out:
#  * ibm_db_sa://njg88036:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB
# Done.
# [(2928,)]

# %% [markdown]
# ### Task 5

# %%
# %%sql
#
# SELECT min(Date) as Earliest_Date from SPACEXTBL where Outcome = 'Success (ground pad)'
# Out:
#  * ibm_db_sa://njg88036:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB
# Done.
# [(datetime.date(2015, 12, 22),)]

# %% [markdown]
# ### Task 6

# %%
# %%sql
#
# select BOOSTER_VERSION from SPACEXTBL
# where OUTCOME='Success (drone ship)' and PAYLOAD_MASS__KG_ BETWEEN 4001 and 6000
# Out:
#  * ibm_db_sa://njg88036:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB
# Done.
# [('F9 FT B1022',), ('F9 FT B1026',), ('F9 FT  B1021.2',), ('F9 FT  B1031.2',)]

# %% [markdown]
# ### Task 7

# %%
# %%sql
#
# Select MISSION_OUTCOME, COUNT(MISSION_OUTCOME) as OUTCOME from SPACEXTBL GROUP BY MISSION_OUTCOME
# Out:
#  * ibm_db_sa://njg88036:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB
# Done.
# [('Failure (in flight)', 1),
#  ('Success', 99),
#  ('Success (payload status unclear)', 1)]

# %% [markdown]
# ### Task 8

# %%
# %%sql
#
# select BOOSTER_VERSION from SPACEXTBL
# where PAYLOAD_MASS__KG_ = (select MAX(PAYLOAD_MASS__KG_) FROM SPACEXTBL)
# Out:
#  * ibm_db_sa://njg88036:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB
# Done.
# [('F9 B5 B1048.4',),
#  ('F9 B5 B1049.4',),
#  ('F9 B5 B1051.3',),
#  ('F9 B5 B1056.4',),
#  ('F9 B5 B1048.5',),
#  ('F9 B5 B1051.4',),
#  ('F9 B5 B1049.5',),
#  ('F9 B5 B1060.2',),
#  ('F9 B5 B1058.3',),
#  ('F9 B5 B1051.6',),
#  ('F9 B5 B1060.3',),
#  ('F9 B5 B1049.7',)]

# %% [markdown]
# ### Task 9

# %%
# %%sql
#
# Select DATE, BOOSTER_VERSION, LAUNCH_SITE, OUTCOME from SPACEXTBL
# where OUTCOME = 'Failure (drone ship)' and year(date) ='2015'
# Out:
#  * ibm_db_sa://njg88036:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB
# Done.
# [(datetime.date(2015, 1, 10), 'F9 v1.1 B1012', 'CCAFS LC-40', 'Failure (drone ship)'),
#  (datetime.date(2015, 4, 14), 'F9 v1.1 B1015', 'CCAFS LC-40', 'Failure (drone ship)')]

# %% [markdown]
# ### Task 10

# %%
# %%sql
# Select OUTCOME, COUNT(*) as COUNT_LAUNCHES from SPACEXTBL
# Where DATE BETWEEN '2010-06-04' and '2017-03-20' group by OUTCOME
# Out:
#  * ibm_db_sa://njg88036:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB
# Done.
# [('Controlled (ocean)', 3),
#  ('Failure (drone ship)', 5),
#  ('Failure (parachute)', 2),
#  ('No attempt', 10),
#  ('Precluded (drone ship)', 1),
#  ('Success (drone ship)', 5),
#  ('Success (ground pad)', 3),
#  ('Uncontrolled (ocean)', 2)]
